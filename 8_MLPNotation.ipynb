# %% [markdown]
# <a href="https://colab.research.google.com/github/YashVardhanSingh216/Deep-Learning/blob/main/8_MLPNotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('mlp.jpeg')
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.axis('off');
